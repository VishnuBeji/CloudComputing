# %%
import requests
import json
import time
import pandas as pd

# Define the Yelp API key and endpoint
API_KEY = '7BoWFsg38bW_s_b06yYPvSBhV_5Q4xgrI8vmzMqZscYYgx2anEHMyyvkASO-6SLNI4Ivjdl4KGaQF99ndsINfn4qFcdF2dXDMhd2zrbBV1zoXcIIH95NKWQvpC8MZ3Yx'
SEARCH_URL = 'https://api.yelp.com/v3/businesses/search'

# Define headers with your API key
HEADERS = {
    'Authorization': f'Bearer {API_KEY}'
}

# Function to get restaurants from Yelp by cuisine type
def get_restaurants_by_cuisine(cuisine, location='Manhattan', limit=50, offset=0):
    params = {
        'term': cuisine,
        'location': location,
        'limit': limit,
        'offset': offset  # Pagination: Adjust this to get more results
    }
    response = requests.get(SEARCH_URL, headers=HEADERS, params=params)
    return response.json()

# Store results in a DataFrame or a list
def fetch_restaurant_data():
    all_restaurants = []
    cuisines = ['Indian', 'Mexican', 'Italian']  # Define your cuisine types

    for cuisine in cuisines:
        for offset in range(0, 50, 50):  # Yelp limits 50 results per request; so paginate
            print(f"Fetching {cuisine} restaurants with offset {offset}")
            data = get_restaurants_by_cuisine(cuisine, offset=offset)
            
            if 'businesses' in data:
                for restaurant in data['businesses']:
                    all_restaurants.append({
                        'BusinessID': restaurant['id'],
                        'Name': restaurant['name'],
                        'Address': ', '.join(restaurant['location']['display_address']),
                        'Coordinates': restaurant['coordinates'],
                        'NumberOfReviews': restaurant['review_count'],
                        'Rating': restaurant['rating'],
                        'ZipCode': restaurant['location']['zip_code'],
                        'Cuisine': cuisine
                    })
            time.sleep(1)  # Avoid hitting rate limits by adding a delay between requests

    # Convert the list to a DataFrame and save it locally
    df = pd.DataFrame(all_restaurants)
    df.to_csv('restaurants3.csv', index=False)  # Save to CSV
    print(f"Saved {len(all_restaurants)} restaurants to restaurants3.csv")

if __name__ == '__main__':
    fetch_restaurant_data()
# Out:
# Fetching Indian restaurants with offset 0
# Fetching Mexican restaurants with offset 0
# Fetching Italian restaurants with offset 0
# Saved 150 restaurants to restaurants3.csv

# %%
# Load the CSV file after upload
df = pd.read_csv('restaurants3.csv')

# Display the first few rows
print(df.head())
# Out:
#                BusinessID           Name                            Address  \
# 0  x0k5kFArHLijdY8-NEQ7Xg  Bengal Tiger    234W 56th St, New York, NY 10019
# 1  m5Whyz8O8jM4DrE808h71g   Darbar Grill  157 E 55th St, New York, NY 10022
# 2  -mxZcmP2TtgIMmfNmxWMQA        Javitri  132 E 61st St, New York, NY 10065
# 3  u_CnSp9FieAuWqhvCn-A2A   Spice Mantra   1047 2nd Ave, New York, NY 10022
# 4  QqrEF8_ZQCGi63cL10J5oA          Chola  232 E 58th St, New York, NY 10022
#
#                                          Coordinates  NumberOfReviews  Rating  \
# 0  {'latitude': 40.765673188349595, 'longitude': ...             2444     4.5
# 1   {'latitude': 40.759357, 'longitude': -73.968826}              633     4.0
# 2  {'latitude': 40.76358346058178, 'longitude': -...               19     4.6
# 3     {'latitude': 40.75825, 'longitude': -73.96633}               99     4.7
# 4     {'latitude': 40.76016, 'longitude': -73.96582}              706     4.0
#
#    ZipCode Cuisine
# 0    10019  Indian
# 1    10022  Indian
# 2    10065  Indian
# 3    10022  Indian
# 4    10022  Indian

# %%
import requests
import json
from requests.auth import HTTPBasicAuth

# ElasticSearch Endpoint (replace with your actual OpenSearch endpoint)
ES_ENDPOINT = 'https://search-restaurants-domain-bfaqu2hsgnnvgmsspl77vr237u.aos.us-east-1.on.aws'
INDEX = 'restaurants'
DOC_TYPE = '_doc'  #OpenSearch no longer uses types, use _doc for backwards compatibility

# Credentials if required (for simple access policy, you might not need this)
USERNAME = '*******'
PASSWORD = '*******'

def insert_restaurant_data(restaurant_id, cuisine):
    url = f"{ES_ENDPOINT}/{INDEX}/{DOC_TYPE}/{restaurant_id}"
    headers = {
        'Content-Type': 'application/json'
    }
    data = {
        "RestaurantID": restaurant_id,
        "Cuisine": cuisine
    }
    #
    response = requests.put(url, auth=HTTPBasicAuth(USERNAME, PASSWORD), headers=headers, data=json.dumps(data))
    
    if response.status_code == 201:
        print(f"Successfully inserted {restaurant_id}")
    else:
        print(f"Failed to insert {restaurant_id}: {response.text}")

# Example usage

restaurants = [
    {
        "RestaurantID": row["BusinessID"],
        "Cuisine": row["Cuisine"]
    }
    for index, row in df.iterrows()
]

for restaurant in restaurants:
    insert_restaurant_data(restaurant['RestaurantID'], restaurant['Cuisine'])
# Out:
# Successfully inserted x0k5kFArHLijdY8-NEQ7Xg
# Successfully inserted m5Whyz8O8jM4DrE808h71g
# Successfully inserted -mxZcmP2TtgIMmfNmxWMQA
# Successfully inserted u_CnSp9FieAuWqhvCn-A2A
# Successfully inserted QqrEF8_ZQCGi63cL10J5oA
# Successfully inserted XLEdQl5s1bO5Iu43W_c96Q
# Successfully inserted IysZ64t48AedrhWfz3WJGQ
# Successfully inserted A-ert0jDRBfku9ogyW_mEg
# Successfully inserted 1_pK5aQ47atF50oAKHADhA
# Successfully inserted izRJeBfDQYJmd6ibIQ6Mfg
# Successfully inserted 3Lzq6WS7q0Cz9_RinS00OA
# Successfully inserted t6PzD4uzBOfyCLcd_lT8cQ
# Successfully inserted juAQ4DHCW_24LpV1T1JmBA
# Successfully inserted _7BGw3YFNOTzP1Www3zB7g
# Successfully inserted wBwTAHhfSm5hpJU-InCUdw
# Successfully inserted guwS_mhhUjOT5d8sYfEluQ
# Successfully inserted GNPne4Il-itbn2sLbvMo1g
# Successfully inserted z2VXX7wGl8XZ6_oo9W3koA
# Successfully inserted 9pMhRYYgV7E9L7pzECtJKA
# Successfully inserted 50eKjWOB-H9iuo1ocACOaQ
# Successfully inserted 1KGvtMU7VBcdlvxo2brdQg
# Successfully inserted 7DzfrwNwXmbS6OhYxPKfHQ
# Successfully inserted UiG3MlLDMMZp31XDBM2kvA
# Successfully inserted ut-560tVcs2g-ZU0Y_qqHQ
# Successfully inserted eTzH9lmkmouNlmuJ77i8Ow
# Successfully inserted objNX6cuj1JyUijFjw21Qw
# Successfully inserted 7USPKYeaAfxl0Ch9j_1l7A
# Successfully inserted ePn4BwyXeY8NKN-MWSgfrQ
# Successfully inserted ECUTH1VOWxZ9GwfzblMKzA
# Successfully inserted 3hlAeWgSKAnSQ1tg8k8D8g
# Successfully inserted Xqk91WuhMeYS4pedccUYgA
# Successfully inserted SP4bvMvxel_UPdof_er3HA
# Successfully inserted 7VIUu8ay754GoUYEpsmxOA
# Successfully inserted XKy4Cy4uNgO7rxhH4yFJQQ
# Successfully inserted o1odYIRiARdSTRsRI776Fg
# Successfully inserted lxNU-aBq0yPwBDx-i89ahA
# Successfully inserted cJ1Uf4MlR4egrG-lbfh8oA
# Successfully inserted qhXIW0LDT4XsoN2IE6dZHg
# Successfully inserted 5dyFdzcYr_GNem5BFApeeg
# Successfully inserted FqYgcc7Mk2XrYJ10OGgghQ
# Successfully inserted ZNJ4ij7_xOlKSeMeEh1khA
# Successfully inserted jf3JRaxUYU93x8LFU-8gkA
# Successfully inserted NhBUzlITbu3rdjm9UEfWsw
# Successfully inserted Xl-zlT0NLLiKhym88em22w
# Successfully inserted KbCLZOKvPdNY7ptAg0kGxw
# Successfully inserted Txm8KtUh9Mn2E7980jTr5g
# Successfully inserted CVpha6hKVu_r1lx6JxNIPg
# Successfully inserted JSX6Pk56w4BhgO8eSvCrKg
# Successfully inserted iLjrQvbUYPj6NLkalyau0w
# Successfully inserted NgD-6ogFGc_c4z5_Ur4k2g
# Successfully inserted MaoCNdHni6MLjM9iYQqHcg
# Successfully inserted kBpYAEbDHlf-yFjmUBYhlw
# Successfully inserted SOWmvC20kikJBoWE3TmppA
# Successfully inserted 6Ct7OeTRn4caY9g0swFBsw
# Successfully inserted Wx6lMnEh7dCmX-9PQF1Ifw
# Successfully inserted 4UxmxAqehEIh7fYrzUEA7A
# Successfully inserted Xjswj531-FkRZPpcccU6kQ
# Successfully inserted SeI-nIE1Ab5U53mB_e-1KQ
# Successfully inserted 7ERwg_4Kiaq1ezKTSSv7pg
# Successfully inserted YFL1rAdlv7J0cswHVhvCtQ
# Successfully inserted SULHf6nGQ8sK0UpG1XU30w
# Successfully inserted HjvCwjM0EkFoYo8TFHjfww
# Successfully inserted BsDu_kup3lJ2QHb-Botpeg
# Successfully inserted 8SdKtlwT9vcowN4veZ8Sjw
# Successfully inserted qnXMxa7WokNT_0fYCGT38w
# Successfully inserted TXLtPStqbC3acOpoHWDfYQ
# Successfully inserted 7bD22UAtH56ikWYslOSIQg
# Successfully inserted ihzI-4yGesoQuAoIocao8g
# Successfully inserted PqqnNrUtU7XTKQvUM4cyqQ
# Successfully inserted 6ezrABEThm48qv1qj8_FVw
# Successfully inserted MwyEUg5EXuqTf1mjKU08ng
# Successfully inserted a2BkT6uUKDpzhLalkksJsg
# Successfully inserted _2jMPuiK-7nLepFdPu2TTQ
# Successfully inserted U6l20gH8YuOJMO8vF6_Ufw
# Successfully inserted UjBZR0Vyl5zpwDVkOvNceQ
# Successfully inserted 7Yh4Zp-l3is-4V9MrDoAIw
# Successfully inserted AFMskIEWMA-9mawqSFEuqg
# Successfully inserted PAJdNrD4HFBN16OAFeDx4A
# Successfully inserted v8tuFxvNkKdZytWTn9BhMA
# Successfully inserted L3REPLCvQpMapYPd_fkS-A
# Successfully inserted eM5uNo9gsztpqAFBqwWWxA
# Successfully inserted 0ksKKrgHt-6xCCHfTlLcoA
# Successfully inserted PHMkwS5nmo4IUXbcg0OcAg
# Successfully inserted vyKBwzRdNX4yiJDIFv37iw
# Successfully inserted vpWPgusmUD0cYNKf0uEQIw
# Successfully inserted 4GPZAkK7M9ObDBsgMq7JSA
# Successfully inserted xWLSJOiN1mMRHmBmHyjAfw
# Successfully inserted Zk8UgB9MDoIHWFYgAxNlIQ
# Successfully inserted ED91L2kUw_pwF_Pd1ZdViQ
# Successfully inserted dYWjNK07igws9jFNgQmhng
# Successfully inserted twQFM-8T_Y4yYIqeEPk4XQ
# Successfully inserted tvqtAjAyc7dplVVwhw3VZQ
# Successfully inserted kn9rgR4KlvyTTi-s76OIaQ
# Successfully inserted DFRpXRHjOHBxYHiuvwaEQQ
# Successfully inserted 2VdLKWG8e3bT7fTng4UNBg
# Successfully inserted cy0vBvZu2Eb4XtRFCp8Seg
# Successfully inserted hKkPlYmHoS9Nb_UbGGqx8A
# Successfully inserted IfIyjm4SfORGYPbaAWST3g
# Successfully inserted B6bEkY9sJ_GU2pD2Rwb4gg
# Successfully inserted EHUNrnIgnhwTnpOm3gEESg
# Successfully inserted 16ZnHpuaaBt92XWeJHCC5A
# Successfully inserted dEOv8_ivdHp85OK_TDQh_g
# Successfully inserted VmdyRRMtUXOWV7F7w0ImwQ
# Successfully inserted hdiuRS9sVZSMReZm4oV5SA
# Successfully inserted EM0JnhfXWwr_Nqw4_AjWAA
# Successfully inserted DoSU8IPq-Py_YV3kYmXPfQ
# Successfully inserted JFmWkslCGTeuwC_Yews4-Q
# Successfully inserted CIzl1SAhtNUGEkLgvTB9zQ
# Successfully inserted WG639VkTjmK5dzydd1BBJA
# Successfully inserted HR49vM1-kwejaSTwVrEfBw
# Successfully inserted HodL0fXoF08C3Ir-kLeTtw
# Successfully inserted q3_FgDWWuXcVGiNuo_OPBQ
# Successfully inserted hkooeEkd3oPsLD6JJrYpjA
# Successfully inserted Zp-K3ztVTzR-LrWwl_CBgA
# Successfully inserted zYaYXpmlo6QdnaPwuxWHhQ
# Successfully inserted vjubSxmdG_HoBBgd39geBw
# Successfully inserted rp8S7scxOkVVeG7dNneMGQ
# Successfully inserted 5TX0X8w5ssIACU_pnBEq6g
# Successfully inserted 5EQOEAkH2Qh3Rv1TcnE7yA
# Successfully inserted 7_hGsGEkHrjgAiYVjrCFnw
# Successfully inserted raqwXUBlnc0e8c7CYmxEJQ
# Successfully inserted fyC2cBsQ0FsMJmv0jSworg
# Successfully inserted vVVmHacu2YAxKfpIjhfd1g
# Successfully inserted h37t9rA06Sr4EetJjKrfzw
# Successfully inserted wZYbXxPDQ0rnHhA5XKuhfg
# Successfully inserted OAqsZMbjv66nOMqlimnYuQ
# Successfully inserted LkV96_buOU_n0br4SBO57w
# Successfully inserted 6eqrk1wCQMww_ejze5gvsg
# Successfully inserted dc3hkLkAqCSxDWQzrx-g9A
# Successfully inserted JLpEKUYAtzBRQwsUL3RPIA
# Successfully inserted Qro_lPPQZ9_cehKG7MIi7g
# Successfully inserted l7OsDvMOO3ji3fg0nT0QzA
# Successfully inserted nBy8KtcUHktPFKw-VClG1A
# Successfully inserted lgFApPVpbXnsIFw1CRJORw
# Successfully inserted 8oO6j7AlnAbMSJs9Oj9GIw
# Successfully inserted Z-QmxQZAJEy5GXqA82Bemw
# Successfully inserted V3USzFEGhuoXez4G2Rk11A
# Successfully inserted 15k7iqFbhf4h8L01yggLqg
# Successfully inserted NlmP5x_Ykznd55Dc85ChUg
# Successfully inserted OWNmOq-TAsHjGcYdCVclSw
# Successfully inserted rpVX-o82EEOX8ZDnM28a_Q
# Successfully inserted hveuXFWS53S1wWpaK0nokw
# Successfully inserted TzVVPWK_4dhdSEpNqZwIhQ
# Successfully inserted 22nKUyCIbpnzR6R3_g1ptQ
# Successfully inserted JBthOvTegHbrLDiVaCAy5Q
# Successfully inserted eMqKFQbKQXq82EUVnlPguw
# Successfully inserted RbiXVG4tzpC3zuILadyPIQ
# Successfully inserted MOwB9YYd-Ko6nVgSB-ltQw
# Successfully inserted JwCnSW-RQ7_DxvbzWNO1hA
# Successfully inserted HiNUBUR1hFwScd_OvVLQAg

# %%
df
# Out:
#                  BusinessID                     Name  \
# 0    x0k5kFArHLijdY8-NEQ7Xg            Bengal Tiger
# 1    m5Whyz8O8jM4DrE808h71g             Darbar Grill
# 2    -mxZcmP2TtgIMmfNmxWMQA                  Javitri
# 3    u_CnSp9FieAuWqhvCn-A2A             Spice Mantra
# 4    QqrEF8_ZQCGi63cL10J5oA                    Chola
# ..                      ...                      ...
# 145  eMqKFQbKQXq82EUVnlPguw  Bar Primi Penn District
# 146  RbiXVG4tzpC3zuILadyPIQ     La Pecora Bianca UWS
# 147  MOwB9YYd-Ko6nVgSB-ltQw                 Briciola
# 148  JwCnSW-RQ7_DxvbzWNO1hA                  Coletta
# 149  HiNUBUR1hFwScd_OvVLQAg   La Pecora Bianca NoMad
#
#                                   Address  \
# 0        234W 56th St, New York, NY 10019
# 1       157 E 55th St, New York, NY 10022
# 2       132 E 61st St, New York, NY 10065
# 3        1047 2nd Ave, New York, NY 10022
# 4       232 E 58th St, New York, NY 10022
# ..                                    ...
# 145     349 W 33rd St, New York, NY 10001
# 146  359 Columbus Ave, New York, NY 10024
# 147     370 W 51st St, New York, NY 10019
# 148       365 3rd Ave, New York, NY 10016
# 149     1133 Broadway, New York, NY 10010
#
#                                            Coordinates  NumberOfReviews  \
# 0    {'latitude': 40.765673188349595, 'longitude': ...             2444
# 1     {'latitude': 40.759357, 'longitude': -73.968826}              633
# 2    {'latitude': 40.76358346058178, 'longitude': -...               19
# 3       {'latitude': 40.75825, 'longitude': -73.96633}               99
# 4       {'latitude': 40.76016, 'longitude': -73.96582}              706
# ..                                                 ...              ...
# 145  {'latitude': 40.7524583, 'longitude': -73.9954...               72
# 146  {'latitude': 40.78049101969648, 'longitude': -...              104
# 147  {'latitude': 40.7637997047278, 'longitude': -7...             1063
# 148     {'latitude': 40.74094, 'longitude': -73.98139}              298
# 149      {'latitude': 40.74358, 'longitude': -73.9892}             1159
#
#      Rating  ZipCode  Cuisine
# 0       4.5    10019   Indian
# 1       4.0    10022   Indian
# 2       4.6    10065   Indian
# 3       4.7    10022   Indian
# 4       4.0    10022   Indian
# ..      ...      ...      ...
# 145     4.3    10001  Italian
# 146     3.9    10024  Italian
# 147     4.0    10019  Italian
# 148     4.6    10016  Italian
# 149     4.0    10010  Italian
#
# [150 rows x 8 columns]
